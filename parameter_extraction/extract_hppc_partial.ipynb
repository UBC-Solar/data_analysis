# %% [markdown]
# If needed, the hardcoded values and bounds in the following cell can be changed. The script assumes there is a file called data.npz which contains data headers: voltage, power and soc. We also assume time ticks are 1 second.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from data_tools.query import DBClient 
from data_tools.collections import TimeSeries
import datetime

from dotenv import load_dotenv

load_dotenv()
# Out:
# ERROR:data_tools.query.postgresql_query:Could not find a POSTGRESQL_USERNAME in .env!
# ERROR:data_tools.query.postgresql_query:Could not find a POSTGRESQL_PASSWORD in .env!
# ERROR:data_tools.query.postgresql_query:Could not find a POSTGRESQL_DATABASE in .env!
# ERROR:data_tools.query.postgresql_query:Could not find a POSTGRESQL_ADDRESS in .env!
# True

# %%
client = DBClient(influxdb_token="s4Z9_S6_O09kDzYn1KZcs7LVoCA2cVK9_ObY44vR4xMh-wYLSWBkypS0S0ZHQgBvEV2A5LgvQ1IKr8byHes2LA==", influxdb_org="8a0b66d77a331e96")

start = datetime.datetime.fromisoformat("2025-04-11T00:00:00Z")
stop = datetime.datetime.fromisoformat("2025-04-13T03:00:00Z")

pack_voltage = client.query_time_series(start=start, stop=stop, field="TotalPackVoltage", bucket="CAN_log", granularity=0.1, units="V", car="Brightside")
pack_current = client.query_time_series(start=start, stop=stop, field="PackCurrent", bucket="CAN_log", granularity=0.1, units="A", car="Brightside")
# Out:
# Creating client with API Token: s4Z9_S6_O09kDzYn1KZcs7LVoCA2cVK9_ObY44vR4xMh-wYLSWBkypS0S0ZHQgBvEV2A5LgvQ1IKr8byHes2LA==
# Creating client with Org: 8a0b66d77a331e96

# %%
fig, ax = plt.subplots()

ax2 = ax.twinx()
ax.plot(pack_current.datetime_x_axis, pack_current)
ax2.plot(pack_voltage.datetime_x_axis, pack_voltage)
plt.show()

# %%
I_load, U_measured = TimeSeries.align(pack_current, pack_voltage)

# This notebook uses the opposite convention -> negative power = discharging
# InfluxDB and firmware uses the convention where -> positive power = discharging
power = U_measured * -I_load
power -= 2           # ~2 watts of power draw for LEDs, contactors, etc

N = len(U_measured)  # Number of data points

# %%
fig, ax = plt.subplots()

ax2 = ax.twinx()
ax.plot(I_load.datetime_x_axis, I_load)
ax2.plot(U_measured.datetime_x_axis, U_measured)
plt.show()

# %% [markdown]
# We need to identify the SOC that we performed each pulse at; since the battery was relaxed before the pulse begins, we can read it off from the voltage. For this, I'm stealing Jonah's SOC from voltage interpolation code.
#
# I'm going to manually read off indices that are from right before a pulse, and index the SoC from interpolation at those indices.

# %%
current_mask = np.where(I_load > 0.5)

# %%
from soc_analysis.datasheet_voltage_soc.soc_from_voltage import cell_soc_from_voltage
from soc_analysis.soc import get_soc_from_voltage_at_relaxation

num_modules = 32

# soc_from_interpolation = cell_soc_from_voltage(U_measured / num_modules)
soc_from_interpolation = get_soc_from_voltage_at_relaxation(U_measured)

# %matplotlib notebook
plt.plot(soc_from_interpolation)

# %%
soc_indices = [-1, 284051, 238416, 192883, 148060, 100789, 56830, 8274]
real_soc_data = soc_from_interpolation[soc_indices]
SOC_data = [0.03544889, 0.05358507, *real_soc_data]
SOC_data = [float(item) for item in SOC_data]
initial_SoC = SOC_data[-1]

# %%
print(SOC_data)
print(f"Initial SoC: {initial_SoC}")
# Out:
# [0.03544889, 0.05358507, 0.18364275532774627, 0.3057634752468827, 0.4240829289692567, 0.512871111489014, 0.6316569585043401, 0.758842328989836, 0.874914895958888, 0.946672231524717]
# Initial SoC: 0.946672231524717

# %% [markdown]
# We need a few more constants.

# %%
# Hardcoded values
Q_estimated = 3300 * 13 * 3.6     # 3300mAh per cell * 32 modules * 12 cells per module * 1 Ah / 1000mAh = Charge Capacity in Ah 
max_current_capacity = 42.9         # 42.9 A max current
max_energy_capacity = 500           # This is not actually used by the battery model, so I set it arbitrarily.

# Bounds derived from conventional battery ranges
initial_guess = (
    [0.2564, 0.2541, 0.2541, 0.2558, 0.2549, 0.2574, 0.2596, 0.2626, 0.2676, 0.2789] +   # R_0_data (Ohmic Resistance)
    [0.595, 0.449, 0.402, 0.383, 0.386, 0.585, 0.558, 0.530, 0.490, 0.466] +   # R_P_data (Polarization Resistance), 
    [4541, 8362, 9538, 10113, 9525, 7402, 7646, 7327, 7658, 8009] +   # C_P_data (Capacitance)
    [2.8 * 32, 2.9 * 32, 3.1 * 32, 3.3 * 32, 3.45 * 32, 3.750 * 32, 3.846 * 32, 3.946 * 32, 4.056 * 32, 4.183 * 32]              # Uoc_data (Open Circuit Voltage)
)

# %%
# Function to plot objective function with initial guess
def plot_results(soc_array, voltage_array, power, U_measured, optimize):
    time = np.arange(len(power))

    plt.figure(figsize=(12, 6))

    # Plot SOC
    plt.subplot(2, 1, 1)
    plt.plot(time, soc_array, label="Predicted State of Charge (SOC)", color="blue")

    plt.xlabel("Time (s)")
    plt.ylabel("SOC (%)")
    if optimize:
        plt.title("Battery Simulation after Optimization: Predicted vs Real State of Charge Over Time")
    else:
        plt.title("Battery Simulation before Optimization: Predicted vs Real State of Charge Over Time")

    plt.grid(True)
    plt.legend()

    # Calculate min/max voltage values
    min_voltage = min(np.min(voltage_array), np.min(U_measured))
    max_voltage = max(np.max(voltage_array), np.max(U_measured))
    margin = (max_voltage - min_voltage) * 0.05  # 5% margin for visibility

    # Plot Voltage
    plt.subplot(2, 1, 2)
    plt.plot(time, voltage_array, label="Predicted Voltage", color="orange")
    plt.plot(time, U_measured, label="Real Voltage", color="red", linestyle="dashed")  # Real voltage added
    plt.xlabel("Time (s)")
    plt.ylabel("Voltage (V)")
    if optimize:
        plt.title("Battery Simulation after Optimization: Predicted vs Real Voltage Over Time")
    else:
        plt.title("Battery Simulation before Optimization: Predicted vs Real Voltage Over Time")


    plt.ylim(min_voltage - margin, max_voltage + margin)  # Adjust Y-axis dynamically
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
from physics.models.battery import BatteryModel, BatteryModelConfig


def run_battery_model(params, total_charge) -> tuple[np.ndarray, np.ndarray]:
    battery_config = BatteryModelConfig(
        R_0_data=params[:10],  # Optimized R_0_data
        R_P_data=params[10:20],        # Optimized R_P
        C_P_data=params[20:30],        # Optimized C_P
        Q_total=total_charge,
        SOC_data=SOC_data,     # Hardcoded SOC data
        Uoc_data=params[30:40],# Optimized Uoc_data
        max_current_capacity=max_current_capacity,
        max_energy_capacity=max_energy_capacity
    )
    bm = BatteryModel(battery_config, state_of_charge=initial_SoC)
    
    # Run Battery Model
    soc_array, U_predicted = bm.update_array(power, power.granularity, rust=True)

    return soc_array, U_predicted


def objective_soc(total_charge, visualize=True, optimized=False):
    # Run Battery Model
    soc_array, U_predicted = run_battery_model(initial_guess, total_charge)

    # Compute Errors
    mse_soc = np.mean((soc_array[soc_indices] - real_soc_data) ** 2)

    # Visualize Results
    if visualize:
        plot_results(soc_array, U_predicted, power, U_measured, optimized)

    return mse_soc
# Out:
# /Users/joshuariefman/Solar/data_analysis/.venv/lib/python3.12/site-packages/filterpy/common/helpers.py:364: SyntaxWarning: invalid escape sequence '\S'
#   """

# %%
from scipy import optimize

# Define the optimization wrapper function
def optimization_wrapper(charge):
    return objective_soc(charge, visualize=False)  # Run without plotting for efficiency

# Perform optimization using SciPy's minimize Powell method
result = optimize.minimize_scalar(optimization_wrapper, method='bounded', bounds=(Q_estimated / 1.25, Q_estimated * 1.25))
objective_soc(result.x, visualize=True, optimized=True)

formatted_params = f"""
🔹 Optimized Parameters:
- Q_total (C): {result.x}

🔹 Final Error (MSE): {result.fun:.12e}
"""

print(formatted_params)
# Out:
# 🔹 Optimized Parameters:
# - Q_total (C): 138536.4486559887
#
# 🔹 Final Error (MSE): 1.337120032878e-04

# %%
nominal_charge_capacity = result.x

# %%
# Define the objective function
def objective_voltage(params, visualize=True, optimized=False):
    # Run Battery Model
    soc_array, U_predicted = run_battery_model(params, nominal_charge_capacity)

    # Compute Errors
    mse_voltage = np.mean((U_measured - U_predicted) ** 2)

    # Visualize Results
    if visualize:
        plot_results(soc_array, U_predicted, power, U_measured, optimized)

    return mse_voltage

objective_voltage(initial_guess)
# Out:
# TimeSeries(27.77373717)

# %%
from sklearn.preprocessing import MinMaxScaler
import warnings


# Original (non-normalized) bounds
lower_bounds = np.array(
    [0.0]*10 +          # R_0_data
    [0.0]*10 +          # R_P_data
    [0.0]*10 +          # C_P_data
    [85.0]*10           # U_oc_data
)
upper_bounds = np.array(
    [1.0]*10 +          # R_0_data
    [1.0]*10 +          # R_P_data
    [50000.0]*10 +      # C_P_data
    [135.0]*10          # U_oc_data
)
bounds = list(zip(lower_bounds, upper_bounds))


# Create a scaler to map [lower_bounds, upper_bounds] <-> [0, 1]
scaler = MinMaxScaler()
scaler.fit(np.vstack([lower_bounds, upper_bounds]))  # shape (2, n_features)


# --- Scaled objective function ---
def scaled_objective(scaled_params):
    real_params = scaler.inverse_transform([scaled_params])[0]
    return objective_voltage(real_params, visualize=False)


def make_callback(patience=100, min_delta=1e-6):
    best = {"val": np.inf, "iter": 0, "last_improved": 0}

    def callback(x, convergence):
        best["iter"] += 1
        real_params = scaler.inverse_transform([x])[0]
        loss = objective_voltage(real_params, visualize=False)

        if loss < best["val"] - min_delta:
            print(f"Iter {best['iter']:3d} | Loss: {loss:.6f}")
            best["val"] = loss
            best["last_improved"] = best["iter"]
            
        elif best["iter"] - best["last_improved"] > patience:
            print(f"Early Stopping: No improvement in {patience} iterations...")
            raise StopIteration

    return callback


# --- Define initial guess and scale it ---
initial_guess_scaled = scaler.transform([initial_guess])[0]


# --- Generate tight population around initial guess (±5% of range) ---
def make_initial_population(guess_scaled, num_individuals, noise_scale=0.05):
    population = [guess_scaled]
    for _ in range(num_individuals - 1):
        noise = noise_scale * (np.random.rand(len(guess_scaled)) - 0.5)
        candidate = np.clip(guess_scaled + noise, 0.0, 1.0)
        population.append(candidate)
    return np.array(population)

population_size = 50  # per DE default
num_params = len(initial_guess)
init_population = make_initial_population(initial_guess_scaled, population_size)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    result = optimize.differential_evolution(
        scaled_objective,
        bounds=[(0.0, 1.0)] * len(lower_bounds),
        init=init_population,
        strategy="rand1bin",
        maxiter=300,
        popsize=population_size,
        tol=1e-4,
        mutation=(0.33, 0.75),
        recombination=0.8,
        callback=make_callback(),
        disp=True
    )
# Out:
# differential_evolution step 1: f(x)= 18.704159920722837
# Iter   1 | Loss: 18.704160
# differential_evolution step 2: f(x)= 15.286153486387898
# Iter   2 | Loss: 15.286153
# differential_evolution step 3: f(x)= 14.053186077077743
# Iter   3 | Loss: 14.053186
# differential_evolution step 4: f(x)= 12.53292511572934
# Iter   4 | Loss: 12.532925
# differential_evolution step 5: f(x)= 10.650966962685875
# Iter   5 | Loss: 10.650967
# differential_evolution step 6: f(x)= 10.650966962685875
# differential_evolution step 7: f(x)= 10.650966962685875
# differential_evolution step 8: f(x)= 9.158356058572965
# Iter   8 | Loss: 9.158356
# differential_evolution step 9: f(x)= 7.873310342906034
# Iter   9 | Loss: 7.873310
# differential_evolution step 10: f(x)= 4.481552921011785
# Iter  10 | Loss: 4.481553
# differential_evolution step 11: f(x)= 4.481552921011785
# differential_evolution step 12: f(x)= 4.145252260476835
# Iter  12 | Loss: 4.145252
# differential_evolution step 13: f(x)= 4.145252260476835
# differential_evolution step 14: f(x)= 2.2700453328908825
# Iter  14 | Loss: 2.270045
# differential_evolution step 15: f(x)= 2.1029467552643095
# Iter  15 | Loss: 2.102947
# differential_evolution step 16: f(x)= 2.1029467552643095
# differential_evolution step 17: f(x)= 1.5668474485757389
# Iter  17 | Loss: 1.566847
# differential_evolution step 18: f(x)= 1.5668474485757389
# differential_evolution step 19: f(x)= 1.5668474485757389
# differential_evolution step 20: f(x)= 1.5668474485757389
# differential_evolution step 21: f(x)= 1.5668474485757389
# differential_evolution step 22: f(x)= 1.397806931934848
# Iter  22 | Loss: 1.397807
# differential_evolution step 23: f(x)= 1.3508902202716258
# Iter  23 | Loss: 1.350890
# differential_evolution step 24: f(x)= 1.3508902202716258
# differential_evolution step 25: f(x)= 1.3508902202716258
# differential_evolution step 26: f(x)= 1.26472142956945
# Iter  26 | Loss: 1.264721
# differential_evolution step 27: f(x)= 0.9258421712893347
# Iter  27 | Loss: 0.925842
# differential_evolution step 28: f(x)= 0.9258421712893347
# differential_evolution step 29: f(x)= 0.9258421712893347
# differential_evolution step 30: f(x)= 0.9258421712893347
# differential_evolution step 31: f(x)= 0.7933457331296592
# Iter  31 | Loss: 0.793346
# differential_evolution step 32: f(x)= 0.7504547691963309
# Iter  32 | Loss: 0.750455
# differential_evolution step 33: f(x)= 0.7504547691963309
# differential_evolution step 34: f(x)= 0.7397628103397893
# Iter  34 | Loss: 0.739763
# differential_evolution step 35: f(x)= 0.7397628103397893
# differential_evolution step 36: f(x)= 0.7397628103397893
# differential_evolution step 37: f(x)= 0.7397628103397893
# differential_evolution step 38: f(x)= 0.7397628103397893
# differential_evolution step 39: f(x)= 0.6637878440304423
# Iter  39 | Loss: 0.663788
# differential_evolution step 40: f(x)= 0.6637878440304423
# differential_evolution step 41: f(x)= 0.6637878440304423
# differential_evolution step 42: f(x)= 0.6637878440304423
# differential_evolution step 43: f(x)= 0.6637878440304423
# differential_evolution step 44: f(x)= 0.6637878440304423
# differential_evolution step 45: f(x)= 0.6637878440304423
# differential_evolution step 46: f(x)= 0.6637878440304423
# differential_evolution step 47: f(x)= 0.6173483749684654
# Iter  47 | Loss: 0.617348
# differential_evolution step 48: f(x)= 0.6173483749684654
# differential_evolution step 49: f(x)= 0.6173483749684654
# differential_evolution step 50: f(x)= 0.6173483749684654
# differential_evolution step 51: f(x)= 0.6173483749684654
# differential_evolution step 52: f(x)= 0.6173483749684654
# differential_evolution step 53: f(x)= 0.6173483749684654
# differential_evolution step 54: f(x)= 0.6173483749684654
# differential_evolution step 55: f(x)= 0.6173483749684654
# differential_evolution step 56: f(x)= 0.6173483749684654
# differential_evolution step 57: f(x)= 0.6173483749684654
# differential_evolution step 58: f(x)= 0.6100335053355594
# Iter  58 | Loss: 0.610034
# differential_evolution step 59: f(x)= 0.5868249194040834
# Iter  59 | Loss: 0.586825
# differential_evolution step 60: f(x)= 0.5868249194040834
# differential_evolution step 61: f(x)= 0.5356907748010569
# Iter  61 | Loss: 0.535691
# differential_evolution step 62: f(x)= 0.5173939181393823
# Iter  62 | Loss: 0.517394
# differential_evolution step 63: f(x)= 0.5173939181393823
# differential_evolution step 64: f(x)= 0.5173939181393823
# differential_evolution step 65: f(x)= 0.5173939181393823
# differential_evolution step 66: f(x)= 0.5173939181393823
# differential_evolution step 67: f(x)= 0.5173939181393823
# differential_evolution step 68: f(x)= 0.4675006462603465
# Iter  68 | Loss: 0.467501
# differential_evolution step 69: f(x)= 0.4675006462603465
# differential_evolution step 70: f(x)= 0.4675006462603465
# differential_evolution step 71: f(x)= 0.4675006462603465
# differential_evolution step 72: f(x)= 0.4675006462603465
# differential_evolution step 73: f(x)= 0.4675006462603465
# differential_evolution step 74: f(x)= 0.4675006462603465
# differential_evolution step 75: f(x)= 0.46682262267868324
# Iter  75 | Loss: 0.466823
# differential_evolution step 76: f(x)= 0.46682262267868324
# differential_evolution step 77: f(x)= 0.46682262267868324
# differential_evolution step 78: f(x)= 0.46682262267868324
# differential_evolution step 79: f(x)= 0.46682262267868324
# differential_evolution step 80: f(x)= 0.46682262267868324
# differential_evolution step 81: f(x)= 0.46682262267868324
# differential_evolution step 82: f(x)= 0.46682262267868324
# differential_evolution step 83: f(x)= 0.46682262267868324
# differential_evolution step 84: f(x)= 0.46682262267868324
# differential_evolution step 85: f(x)= 0.46682262267868324
# differential_evolution step 86: f(x)= 0.335607237693103
# Iter  86 | Loss: 0.335607
# differential_evolution step 87: f(x)= 0.335607237693103
# differential_evolution step 88: f(x)= 0.335607237693103
# differential_evolution step 89: f(x)= 0.335607237693103
# differential_evolution step 90: f(x)= 0.335607237693103
# differential_evolution step 91: f(x)= 0.335607237693103
# differential_evolution step 92: f(x)= 0.335607237693103
# differential_evolution step 93: f(x)= 0.335607237693103
# differential_evolution step 94: f(x)= 0.335607237693103
# differential_evolution step 95: f(x)= 0.335607237693103
# differential_evolution step 96: f(x)= 0.335607237693103
# differential_evolution step 97: f(x)= 0.335607237693103
# differential_evolution step 98: f(x)= 0.335607237693103
# differential_evolution step 99: f(x)= 0.335607237693103
# differential_evolution step 100: f(x)= 0.335607237693103
# differential_evolution step 101: f(x)= 0.335607237693103
# differential_evolution step 102: f(x)= 0.335607237693103
# differential_evolution step 103: f(x)= 0.335607237693103
# differential_evolution step 104: f(x)= 0.335607237693103
# differential_evolution step 105: f(x)= 0.335607237693103
# differential_evolution step 106: f(x)= 0.335607237693103
# differential_evolution step 107: f(x)= 0.335607237693103
# differential_evolution step 108: f(x)= 0.335607237693103
# differential_evolution step 109: f(x)= 0.335607237693103
# differential_evolution step 110: f(x)= 0.335607237693103
# differential_evolution step 111: f(x)= 0.335607237693103
# differential_evolution step 112: f(x)= 0.335607237693103
# differential_evolution step 113: f(x)= 0.335607237693103
# differential_evolution step 114: f(x)= 0.335607237693103
# differential_evolution step 115: f(x)= 0.335607237693103
# differential_evolution step 116: f(x)= 0.335607237693103
# differential_evolution step 117: f(x)= 0.335607237693103
# differential_evolution step 118: f(x)= 0.335607237693103
# differential_evolution step 119: f(x)= 0.335607237693103
# differential_evolution step 120: f(x)= 0.335607237693103
# differential_evolution step 121: f(x)= 0.335607237693103
# differential_evolution step 122: f(x)= 0.335607237693103
# differential_evolution step 123: f(x)= 0.335607237693103
# differential_evolution step 124: f(x)= 0.335607237693103
# differential_evolution step 125: f(x)= 0.335607237693103
# differential_evolution step 126: f(x)= 0.335607237693103
# differential_evolution step 127: f(x)= 0.335607237693103
# differential_evolution step 128: f(x)= 0.335607237693103
# differential_evolution step 129: f(x)= 0.3205397629070097
# Iter 129 | Loss: 0.320540
# differential_evolution step 130: f(x)= 0.3205397629070097
# differential_evolution step 131: f(x)= 0.3205397629070097
# differential_evolution step 132: f(x)= 0.3205397629070097
# differential_evolution step 133: f(x)= 0.3205397629070097
# differential_evolution step 134: f(x)= 0.2879338786910471
# Iter 134 | Loss: 0.287934
# differential_evolution step 135: f(x)= 0.2879338786910471
# differential_evolution step 136: f(x)= 0.2879338786910471
# differential_evolution step 137: f(x)= 0.2879338786910471
# differential_evolution step 138: f(x)= 0.2879338786910471
# differential_evolution step 139: f(x)= 0.2879338786910471
# differential_evolution step 140: f(x)= 0.2879338786910471
# differential_evolution step 141: f(x)= 0.2879338786910471
# differential_evolution step 142: f(x)= 0.2879338786910471
# differential_evolution step 143: f(x)= 0.2879338786910471
# differential_evolution step 144: f(x)= 0.2879338786910471
# differential_evolution step 145: f(x)= 0.2879338786910471
# differential_evolution step 146: f(x)= 0.2879338786910471
# differential_evolution step 147: f(x)= 0.2879338786910471
# differential_evolution step 148: f(x)= 0.2879338786910471
# differential_evolution step 149: f(x)= 0.2879338786910471
# differential_evolution step 150: f(x)= 0.2879338786910471
# differential_evolution step 151: f(x)= 0.2879338786910471
# differential_evolution step 152: f(x)= 0.2879338786910471
# differential_evolution step 153: f(x)= 0.2879338786910471
# differential_evolution step 154: f(x)= 0.2751923709862341
# Iter 154 | Loss: 0.275192
# differential_evolution step 155: f(x)= 0.2751923709862341
# differential_evolution step 156: f(x)= 0.2751923709862341
# differential_evolution step 157: f(x)= 0.2751923709862341
# differential_evolution step 158: f(x)= 0.2751923709862341
# differential_evolution step 159: f(x)= 0.2751923709862341
# differential_evolution step 160: f(x)= 0.2751923709862341
# differential_evolution step 161: f(x)= 0.2751923709862341
# differential_evolution step 162: f(x)= 0.2751923709862341
# differential_evolution step 163: f(x)= 0.2751923709862341
# differential_evolution step 164: f(x)= 0.2751923709862341
# differential_evolution step 165: f(x)= 0.2751923709862341
# differential_evolution step 166: f(x)= 0.2751923709862341
# differential_evolution step 167: f(x)= 0.2751923709862341
# differential_evolution step 168: f(x)= 0.2751923709862341
# differential_evolution step 169: f(x)= 0.2751923709862341
# differential_evolution step 170: f(x)= 0.2751923709862341
# differential_evolution step 171: f(x)= 0.2751923709862341
# differential_evolution step 172: f(x)= 0.2751923709862341
# differential_evolution step 173: f(x)= 0.2751923709862341
# differential_evolution step 174: f(x)= 0.2751923709862341
# differential_evolution step 175: f(x)= 0.2751923709862341
# differential_evolution step 176: f(x)= 0.2751923709862341
# differential_evolution step 177: f(x)= 0.2751923709862341
# differential_evolution step 178: f(x)= 0.2751923709862341
# differential_evolution step 179: f(x)= 0.2751923709862341
# differential_evolution step 180: f(x)= 0.2751923709862341
# differential_evolution step 181: f(x)= 0.27078470058564347
# Iter 181 | Loss: 0.270785
# differential_evolution step 182: f(x)= 0.27078470058564347
# differential_evolution step 183: f(x)= 0.27078470058564347
# differential_evolution step 184: f(x)= 0.27078470058564347
# differential_evolution step 185: f(x)= 0.27078470058564347
# differential_evolution step 186: f(x)= 0.27078470058564347
# differential_evolution step 187: f(x)= 0.27078470058564347
# differential_evolution step 188: f(x)= 0.27078470058564347
# differential_evolution step 189: f(x)= 0.27078470058564347
# differential_evolution step 190: f(x)= 0.27078470058564347
# differential_evolution step 191: f(x)= 0.27078470058564347
# differential_evolution step 192: f(x)= 0.27078470058564347
# differential_evolution step 193: f(x)= 0.27078470058564347
# differential_evolution step 194: f(x)= 0.27078470058564347
# differential_evolution step 195: f(x)= 0.27078470058564347
# differential_evolution step 196: f(x)= 0.25600410677773244
# Iter 196 | Loss: 0.256004
# differential_evolution step 197: f(x)= 0.25600410677773244
# differential_evolution step 198: f(x)= 0.25600410677773244
# differential_evolution step 199: f(x)= 0.25600410677773244
# differential_evolution step 200: f(x)= 0.25600410677773244
# differential_evolution step 201: f(x)= 0.25600410677773244
# differential_evolution step 202: f(x)= 0.25600410677773244
# differential_evolution step 203: f(x)= 0.25600410677773244
# differential_evolution step 204: f(x)= 0.25600410677773244
# differential_evolution step 205: f(x)= 0.25600410677773244
# differential_evolution step 206: f(x)= 0.25600410677773244
# differential_evolution step 207: f(x)= 0.25600410677773244
# differential_evolution step 208: f(x)= 0.25600410677773244
# differential_evolution step 209: f(x)= 0.25600410677773244
# differential_evolution step 210: f(x)= 0.25600410677773244
# differential_evolution step 211: f(x)= 0.25600410677773244
# differential_evolution step 212: f(x)= 0.25600410677773244
# differential_evolution step 213: f(x)= 0.25600410677773244
# differential_evolution step 214: f(x)= 0.25600410677773244
# differential_evolution step 215: f(x)= 0.25600410677773244
# differential_evolution step 216: f(x)= 0.25600410677773244
# differential_evolution step 217: f(x)= 0.25600410677773244
# differential_evolution step 218: f(x)= 0.25600410677773244
# differential_evolution step 219: f(x)= 0.25600410677773244
# differential_evolution step 220: f(x)= 0.25600410677773244
# differential_evolution step 221: f(x)= 0.25600410677773244
# differential_evolution step 222: f(x)= 0.25600410677773244
# differential_evolution step 223: f(x)= 0.25600410677773244
# differential_evolution step 224: f(x)= 0.25600410677773244
# differential_evolution step 225: f(x)= 0.25600410677773244
# differential_evolution step 226: f(x)= 0.25600410677773244
# differential_evolution step 227: f(x)= 0.21668730750499188
# Iter 227 | Loss: 0.216687
# differential_evolution step 228: f(x)= 0.21668730750499188
# differential_evolution step 229: f(x)= 0.21668730750499188
# differential_evolution step 230: f(x)= 0.21668730750499188
# differential_evolution step 231: f(x)= 0.21668730750499188
# differential_evolution step 232: f(x)= 0.21668730750499188
# differential_evolution step 233: f(x)= 0.21668730750499188
# differential_evolution step 234: f(x)= 0.21668730750499188
# differential_evolution step 235: f(x)= 0.21668730750499188
# differential_evolution step 236: f(x)= 0.21668730750499188
# differential_evolution step 237: f(x)= 0.21668730750499188
# differential_evolution step 238: f(x)= 0.21668730750499188
# differential_evolution step 239: f(x)= 0.21668730750499188
# differential_evolution step 240: f(x)= 0.21668730750499188
# differential_evolution step 241: f(x)= 0.21668730750499188
# differential_evolution step 242: f(x)= 0.21668730750499188
# differential_evolution step 243: f(x)= 0.21668730750499188
# differential_evolution step 244: f(x)= 0.21668730750499188
# differential_evolution step 245: f(x)= 0.21668730750499188
# differential_evolution step 246: f(x)= 0.21668730750499188
# differential_evolution step 247: f(x)= 0.21668730750499188
# differential_evolution step 248: f(x)= 0.21668730750499188
# differential_evolution step 249: f(x)= 0.21668730750499188
# differential_evolution step 250: f(x)= 0.21668730750499188
# differential_evolution step 251: f(x)= 0.21668730750499188
# differential_evolution step 252: f(x)= 0.21668730750499188
# differential_evolution step 253: f(x)= 0.21668730750499188
# differential_evolution step 254: f(x)= 0.21668730750499188
# differential_evolution step 255: f(x)= 0.21668730750499188
# differential_evolution step 256: f(x)= 0.21668730750499188
# differential_evolution step 257: f(x)= 0.21668730750499188
# differential_evolution step 258: f(x)= 0.21668730750499188
# differential_evolution step 259: f(x)= 0.21668730750499188
# differential_evolution step 260: f(x)= 0.21668730750499188
# differential_evolution step 261: f(x)= 0.21668730750499188
# differential_evolution step 262: f(x)= 0.21668730750499188
# differential_evolution step 263: f(x)= 0.21668730750499188
# differential_evolution step 264: f(x)= 0.21668730750499188
# differential_evolution step 265: f(x)= 0.21668730750499188
# differential_evolution step 266: f(x)= 0.21668730750499188
# differential_evolution step 267: f(x)= 0.21668730750499188
# differential_evolution step 268: f(x)= 0.21668730750499188
# differential_evolution step 269: f(x)= 0.21668730750499188
# differential_evolution step 270: f(x)= 0.21668730750499188
# differential_evolution step 271: f(x)= 0.21668730750499188
# differential_evolution step 272: f(x)= 0.21668730750499188
# differential_evolution step 273: f(x)= 0.21668730750499188
# differential_evolution step 274: f(x)= 0.21668730750499188
# differential_evolution step 275: f(x)= 0.21668730750499188
# differential_evolution step 276: f(x)= 0.21668730750499188
# differential_evolution step 277: f(x)= 0.21668730750499188
# differential_evolution step 278: f(x)= 0.21668730750499188
# differential_evolution step 279: f(x)= 0.21668730750499188
# differential_evolution step 280: f(x)= 0.21668730750499188
# differential_evolution step 281: f(x)= 0.21668730750499188
# differential_evolution step 282: f(x)= 0.21668730750499188
# differential_evolution step 283: f(x)= 0.21668730750499188
# differential_evolution step 284: f(x)= 0.21668730750499188
# differential_evolution step 285: f(x)= 0.21668730750499188
# differential_evolution step 286: f(x)= 0.21668730750499188
# differential_evolution step 287: f(x)= 0.21668730750499188
# differential_evolution step 288: f(x)= 0.21668730750499188
# differential_evolution step 289: f(x)= 0.21668730750499188
# differential_evolution step 290: f(x)= 0.21668730750499188
# differential_evolution step 291: f(x)= 0.21668730750499188
# differential_evolution step 292: f(x)= 0.21668730750499188
# differential_evolution step 293: f(x)= 0.21668730750499188
# differential_evolution step 294: f(x)= 0.21668730750499188
# differential_evolution step 295: f(x)= 0.21668730750499188
# differential_evolution step 296: f(x)= 0.21668730750499188
# differential_evolution step 297: f(x)= 0.21668730750499188
# differential_evolution step 298: f(x)= 0.21668730750499188
# differential_evolution step 299: f(x)= 0.21668730750499188
# differential_evolution step 300: f(x)= 0.21668730750499188
# Polishing solution with 'L-BFGS-B'

# %%
# result_polished = optimize.minimize(scaled_objective, result.x, method='Powell', bounds=[(0.0, 1.0)] * len(lower_bounds))

final_params = scaler.inverse_transform([result.x])[0]

# Compute MSE for both SOC and Voltage
mse_voltage = objective_voltage(final_params, visualize=True, optimized=True)

# %%
formatted_params = f"""
🔹 Optimized Parameters:
- R_0_data (Ohmic Resistance): {", ".join([f"{x:.6f}" for x in final_params[:10]])}
- R_P (Polarization Resistance): {", ".join([f"{x:.6f}" for x in final_params[10:20]])}
- C_P (Capacitance): {", ".join([f"{x:.6f}" for x in final_params[20:30]])}
- Uoc_data (Open Circuit Voltage): {", ".join([f"{x:.6f}" for x in final_params[30:40]])}
🔹 **Final MSE Voltage:** {mse_voltage:.12e}
"""

print(formatted_params)
# Out:
# 🔹 Optimized Parameters:
# - R_0_data (Ohmic Resistance): 0.643332, 0.511929, 0.293851, 0.175510, 0.227072, 0.260373, 0.158118, 0.255997, 0.232052, 0.291949
# - R_P (Polarization Resistance): 0.376001, 0.258158, 0.720804, 0.266368, 0.586603, 0.623293, 0.615734, 0.414877, 0.498961, 0.367632
# - C_P (Capacitance): 40168.838005, 6146.941928, 3500.455864, 20472.958363, 8574.539961, 9253.620429, 25436.661852, 12165.946555, 9833.394009, 10879.539354
# - Uoc_data (Open Circuit Voltage): 86.796139, 98.029794, 104.173959, 121.034522, 107.976266, 126.664247, 121.595262, 126.731894, 131.293747, 131.714275
# 🔹 **Final MSE Voltage:** 2.166787156215e-01

# %%
raw_params = f"""
R_0_data = {[float(x) for x in final_params[:10]]}
R_P_data = {[float(x) for x in final_params[10:20]]}
C_P_data = {[float(x) for x in final_params[20:30]]}
Uoc_data = {[float(x) for x in final_params[30:40]]}
Q_total = {nominal_charge_capacity}
SOC_data = {[float(x) for x in SOC_data]}
"""

print(raw_params)
# Out:
# R_0_data = [0.6433319269348786, 0.511929455169097, 0.29385126529629246, 0.17551035274152457, 0.22707193540655446, 0.26037310925366935, 0.1581178980204017, 0.25599661609908275, 0.23205230084513087, 0.29194860768049663]
# R_P_data = [0.3760006953341767, 0.25815755397306617, 0.7208042015913289, 0.26636773484364584, 0.5866025935520444, 0.6232934571901527, 0.6157341584730239, 0.41487688694641056, 0.49896128522248356, 0.36763174105108115]
# C_P_data = [40168.83800488115, 6146.941928040834, 3500.4558643832365, 20472.958362998317, 8574.53996051862, 9253.620429078986, 25436.661851909583, 12165.946555189403, 9833.394009094065, 10879.539354347358]
# Uoc_data = [86.79613890793446, 98.02979380814858, 104.17395910667184, 121.03452201586413, 107.97626569876715, 126.66424652286352, 121.59526183984346, 126.73189389502457, 131.2937472514379, 131.71427494455244]
# Q_total = 138536.4486559887
# SOC_data = [0.03544889, 0.05358507, 0.18364275532774627, 0.3057634752468827, 0.4240829289692567, 0.512871111489014, 0.6316569585043401, 0.758842328989836, 0.874914895958888, 0.946672231524717]

# %%
final_result = objective_voltage(final_params, visualize=True, optimized=True)
# plt.savefig("result.png")
print(final_result)
plt.show()
# Out:
# 0.21667871562151383

# %%
battery_config = BatteryModelConfig(
    R_0_data=final_params[:10],  # Optimized R_0_data
    R_P_data=final_params[10:20],        # Optimized R_P
    C_P_data=final_params[20:30],        # Optimized C_P
    Q_total=nominal_charge_capacity,
    SOC_data=SOC_data,     # Hardcoded SOC data
    Uoc_data=final_params[30:40],# Optimized Uoc_data
    max_current_capacity=max_current_capacity,
    max_energy_capacity=max_energy_capacity
)
bm = BatteryModel(battery_config)

# Run Battery Model
soc_array, U_predicted = bm.update_array(power, power.granularity, rust=True)
