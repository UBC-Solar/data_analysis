# %% [markdown]
# While creating plots for various factors' effects on overall lap efficiency, we have collected data for a large number of metrics. For some, we have seen very strong correlations -- for example between accelerator position and motor current. For others, we see weaker or no correlation. One tool we can use to consisely present these correlations and possible reveal the underlying reasons for these is a correlation matrix, which displays r-values. We can use numpy's inbuilt tools to create such a matrix given a list of data sets.
#
# Since we already have the means to effectively compute values on a per-lap basis, our data will be broken down by lap in this analysis. More continuous analysis might also yield interesting results, and should be studied further as well.
#
# We begin this analysis by collecting various arrays (indexed by lap) with possibly correlated data.

# %%
from data_tools import TimeSeries, DBClient, FSGPDayLaps
from typing import Callable
import matplotlib.pyplot as plt
import numpy as np
import datetime

from numpy import ndarray

FSGP_TRACK_LEN_M = 5_070

driver_colours = {
    "Alex": "red",
    "Bryan": "orange",
    "Diego": "green",
    "Phoebe": "blue"
}

data_client = DBClient("can_log_prod")
# Out:
# Creating client with API Token: s4Z9_S6_O09kDzYn1KZcs7LVoCA2cVK9_ObY44vR4xMh-wYLSWBkypS0S0ZHQgBvEV2A5LgvQ1IKr8byHes2LA==
# Creating client with Org: 8a0b66d77a331e96

# %%
def lap_current_ts(start_time: datetime, end_time: datetime, client: DBClient) -> TimeSeries:
    raw_motor_current: TimeSeries = client.query_time_series(start_time, end_time, "BatteryCurrent")
    motor_current_dir: TimeSeries = client.query_time_series(start_time, end_time, "BatteryCurrentDirection")

    # Align x-axes
    raw_motor_current, motor_current_dir = TimeSeries.align(raw_motor_current, motor_current_dir)
    # Make direction -1 or 1 instead of 1 or 0
    motor_current_sign = motor_current_dir * -2 + 1

    # Account for regen direction
    motor_current = raw_motor_current.promote(raw_motor_current * motor_current_sign)
    motor_current.units = "A"
    motor_current.meta["field"] = "Motor Current (adjusted for regen)"
    return motor_current

# %%
def lap_power_ts(start_time: datetime, end_time: datetime, client: DBClient) -> TimeSeries:
    motor_voltage: TimeSeries = client.query_time_series(start_time, end_time, "BatteryVoltage")
    motor_current = lap_current_ts(start_time, end_time, client)

    # Align x-axes
    motor_voltage, motor_current = TimeSeries.align(motor_voltage, motor_current)

    motor_power = motor_current.promote(motor_current * motor_voltage)
    motor_power.units = "W"
    motor_power.meta["field"] = "Motor Power (adjusted for regen)"
    return motor_power

# %%
def lap_energy_ts(start_time: datetime, end_time: datetime, client) -> TimeSeries:
    motor_power = lap_power_ts(start_time, end_time, client)
    motor_energy = np.cumsum(motor_power) * motor_power.granularity
    motor_energy.units = "J"
    motor_energy.meta["field"] = "Motor Energy (regen adjusted)"
    return motor_energy

# %%
def lap_speed_ts(start_time: datetime, end_time: datetime, client: DBClient) -> TimeSeries:
    lap_speed: TimeSeries = client.query_time_series(start_time, end_time, "VehicleVelocity")

    lap_speed.units = "m/s"
    lap_speed.meta["field"] = "Speed"
    return lap_speed

# %%
def lap_accel_ts(start_time: datetime, end_time: datetime, client: DBClient) -> TimeSeries:
    accelerator_position: TimeSeries = client.query_time_series(start_time, end_time, "AcceleratorPosition")

    accelerator_position.units = "%"
    accelerator_position.meta["field"] = "Accelerator Position"
    return accelerator_position

# %%
# Select which FSGP 2024 day to calculate lap efficiency for (1, 2 or 3)
laps1 = FSGPDayLaps(1)  # Corresponds to July 16th
laps3 = FSGPDayLaps(3)  # Corresponds to July 18th
day_1_idx = range(laps1.get_lap_count())
day_3_idx = range(laps3.get_lap_count())
num_laps = len(day_1_idx) + len(day_3_idx)


def collect_lap_data(query_func: Callable) -> ndarray:
    """
    Higher order function - computes `query_func` for all laps and returns the resulting array.

    :param query_func: must take in parameters (lap_start: datetime, lap_end:datetime, data_client:DBClient)
    :return: array of query_func results for all laps
    """
    lap_data = []
    # Iterate through all selected laps
    for day_laps, lap_indices in zip((laps1, laps3), (day_1_idx, day_3_idx)):
        for lap_idx in lap_indices:
            lap_num = lap_idx + 1
            lap_start = day_laps.get_start_utc(lap_num)
            lap_end = day_laps.get_finish_utc(lap_num)
            lap_data.append(query_func(lap_start, lap_end, data_client))
            print(f"Processed data for day {day_laps.day} lap {lap_num}")
            print(f"{lap_start=}\n{lap_end=}")
            print(f"{query_func.__name__} result for lap {lap_num}: {lap_data[-1]}\n")
    return np.array(lap_data)

# %%
# Get lap average speed and driver data
lap_speeds = []
lap_drivers = []

for day_laps, lap_indices in zip((laps1, laps3), (day_1_idx, day_3_idx)):
    for lap_idx in lap_indices:
        lap_num = lap_idx + 1
        lap_start = day_laps.get_start_utc(lap_num)
        lap_end = day_laps.get_finish_utc(lap_num)
        lap_drivers.append(day_laps.get_lap_driver(lap_num))
        lap_speeds.append(day_laps.get_lap_mph(lap_num))

lap_drivers = np.array(lap_drivers)
lap_speeds = np.array(lap_speeds)

# %%
def get_lap_distance(start, end, client):
    speed_array: TimeSeries = lap_speed_ts(start, end, client)  # in meters per second
    return np.sum(speed_array) * speed_array.granularity  # in meters
lap_distances_m = collect_lap_data(get_lap_distance)

def lap_total_energy(start, end, client):
    return lap_energy_ts(start, end, client)[-1]
lap_energies = collect_lap_data(lap_total_energy)

lap_efficiencies = lap_energies / FSGP_TRACK_LEN_M

def get_speed_variance(start, end, client):
    return np.var(lap_speed_ts(start, end, client).base)
lap_speed_variances = collect_lap_data(get_speed_variance)

def get_power_variance(start, end, client):
    return np.var(lap_power_ts(start, end, client).base)
lap_power_variances = collect_lap_data(get_power_variance)

def get_accelerator_variance(start, end, client):
    return np.var(lap_accel_ts(start, end, client).base)
lap_accelerator_variances = collect_lap_data(get_accelerator_variance)

def get_average_acceleration(start, end, client):
    return np.mean(lap_accel_ts(start, end, client).base)
lap_average_accelerations = collect_lap_data(get_average_acceleration)

def get_current_variance(start, end, client):
    return np.var(lap_current_ts(start, end, client).base)
lap_current_variances = collect_lap_data(get_current_variance)

def get_average_current(start, end, client):
    return np.mean(lap_current_ts(start, end, client).base)
lap_average_currents = collect_lap_data(get_average_current)

def get_accel_variance(start, end, client):
    return np.var(np.diff(lap_speed_ts(start, end, client)))
lap_accel_variance = collect_lap_data(get_accel_variance)

def get_rms_accel(start, end, client):
    return np.sqrt(np.mean(np.square(np.diff(lap_speed_ts(start, end, client)))))
rms_accel = collect_lap_data(get_rms_accel)
# Out:
# Processed data for day 1 lap 1
# lap_start=datetime.datetime(2024, 7, 16, 15, 0, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 1: 5425.417711959088
#
# Processed data for day 1 lap 2
# lap_start=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 2: 5121.933540992318
#
# Processed data for day 1 lap 3
# lap_start=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 3: 5098.6438243688335
#
# Processed data for day 1 lap 4
# lap_start=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 4: 5182.615597100614
#
# Processed data for day 1 lap 5
# lap_start=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 5: 5125.517488677095
#
# Processed data for day 1 lap 6
# lap_start=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 6: 5158.282976121215
#
# Processed data for day 1 lap 7
# lap_start=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 7: 5282.060546246367
#
# Processed data for day 1 lap 8
# lap_start=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 8: 5162.499252688673
#
# Processed data for day 1 lap 9
# lap_start=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 9: 5117.129604128573
#
# Processed data for day 1 lap 10
# lap_start=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 10: 5161.095292256347
#
# Processed data for day 1 lap 11
# lap_start=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 11: 5141.047268245204
#
# Processed data for day 1 lap 12
# lap_start=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 12: 5090.493108261697
#
# Processed data for day 1 lap 13
# lap_start=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 13: 5157.652137129129
#
# Processed data for day 1 lap 14
# lap_start=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 14: 5129.265621957187
#
# Processed data for day 1 lap 15
# lap_start=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 15: 5160.5915900294585
#
# Processed data for day 1 lap 16
# lap_start=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 16: 5140.953340645266
#
# Processed data for day 1 lap 17
# lap_start=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 17: 5143.269912329224
#
# Processed data for day 1 lap 18
# lap_start=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 18: 5138.5555098422565
#
# Processed data for day 1 lap 19
# lap_start=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 19: 5122.5499962953345
#
# Processed data for day 1 lap 20
# lap_start=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 20: 5135.883103954759
#
# Processed data for day 1 lap 21
# lap_start=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 21: 5132.815958249855
#
# Processed data for day 1 lap 22
# lap_start=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 22: 5139.930429277633
#
# Processed data for day 1 lap 23
# lap_start=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 23: 5147.181602959824
#
# Processed data for day 1 lap 24
# lap_start=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 24: 5128.249409951228
#
# Processed data for day 1 lap 25
# lap_start=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 25: 5139.4946761054725
#
# Processed data for day 1 lap 26
# lap_start=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 26: 5134.348990881722
#
# Processed data for day 1 lap 27
# lap_start=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 27: 5166.532177288508
#
# Processed data for day 1 lap 28
# lap_start=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 16, 13, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 28: 4443.966267931625
#
# Processed data for day 1 lap 29
# lap_start=datetime.datetime(2024, 7, 16, 18, 19, 48, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 29: 5346.370186037693
#
# Processed data for day 1 lap 30
# lap_start=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 30: 5148.6999569583495
#
# Processed data for day 1 lap 31
# lap_start=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 31: 5138.557935988942
#
# Processed data for day 1 lap 32
# lap_start=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 47, 36, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 32: 4442.46622242794
#
# Processed data for day 1 lap 33
# lap_start=datetime.datetime(2024, 7, 16, 18, 56, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 33: 5269.304476321668
#
# Processed data for day 1 lap 34
# lap_start=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 34: 5124.019170223181
#
# Processed data for day 1 lap 35
# lap_start=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 35: 5109.481501529425
#
# Processed data for day 1 lap 36
# lap_start=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 36: 5071.075353671102
#
# Processed data for day 1 lap 37
# lap_start=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 37: 5122.606348278119
#
# Processed data for day 1 lap 38
# lap_start=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 38: 5111.592390888605
#
# Processed data for day 1 lap 39
# lap_start=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 39: 5060.961290898745
#
# Processed data for day 1 lap 40
# lap_start=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 40: 5095.343576998497
#
# Processed data for day 1 lap 41
# lap_start=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 41: 5094.780300525304
#
# Processed data for day 1 lap 42
# lap_start=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 42: 5051.73789289609
#
# Processed data for day 1 lap 43
# lap_start=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 43: 5040.619129295639
#
# Processed data for day 1 lap 44
# lap_start=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 44: 5034.388493634699
#
# Processed data for day 1 lap 45
# lap_start=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 45: 5051.122896514851
#
# Processed data for day 1 lap 46
# lap_start=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 39, 40, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 46: 5040.428053703058
#
# Processed data for day 3 lap 1
# lap_start=datetime.datetime(2024, 7, 18, 14, 17, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 1: 5158.28058533898
#
# Processed data for day 3 lap 2
# lap_start=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 2: 5134.20039634412
#
# Processed data for day 3 lap 3
# lap_start=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 3: 5121.344565128088
#
# Processed data for day 3 lap 4
# lap_start=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 4: 5116.517390245142
#
# Processed data for day 3 lap 5
# lap_start=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 5: 5121.497551446429
#
# Processed data for day 3 lap 6
# lap_start=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 6: 5120.47737260786
#
# Processed data for day 3 lap 7
# lap_start=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 7: 5132.311227616275
#
# Processed data for day 3 lap 8
# lap_start=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 8: 5163.538181534912
#
# Processed data for day 3 lap 9
# lap_start=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 9: 5117.139200413823
#
# Processed data for day 3 lap 10
# lap_start=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 10: 5167.644066859939
#
# Processed data for day 3 lap 11
# lap_start=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 11: 5125.5015638322975
#
# Processed data for day 3 lap 12
# lap_start=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 12: 5121.80607700662
#
# Processed data for day 3 lap 13
# lap_start=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 13: 5177.400995663858
#
# Processed data for day 3 lap 14
# lap_start=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 14: 5114.447694653795
#
# Processed data for day 3 lap 15
# lap_start=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 15: 5174.338981735403
#
# Processed data for day 3 lap 16
# lap_start=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 16: 5153.469456096859
#
# Processed data for day 3 lap 17
# lap_start=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 17: 5120.6594089948085
#
# Processed data for day 3 lap 18
# lap_start=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 18: 5167.126448934906
#
# Processed data for day 3 lap 19
# lap_start=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 19: 5114.603443133599
#
# Processed data for day 3 lap 20
# lap_start=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 20: 5128.776014215923
#
# Processed data for day 3 lap 21
# lap_start=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 21: 5110.438538299676
#
# Processed data for day 3 lap 22
# lap_start=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 22: 5171.433498581249
#
# Processed data for day 3 lap 23
# lap_start=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 23: 5131.1132056547485
#
# Processed data for day 3 lap 24
# lap_start=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 24: 5019.669512652551
#
# Processed data for day 3 lap 25
# lap_start=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 25: 5244.045527099007
#
# Processed data for day 3 lap 26
# lap_start=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 25, 58, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 26: 4382.360032809408
#
# Processed data for day 3 lap 27
# lap_start=datetime.datetime(2024, 7, 18, 17, 33, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 27: 5382.048249361794
#
# Processed data for day 3 lap 28
# lap_start=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 28: 5094.232984579153
#
# Processed data for day 3 lap 29
# lap_start=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 29: 5086.282935568218
#
# Processed data for day 3 lap 30
# lap_start=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 30: 5124.78526994218
#
# Processed data for day 3 lap 31
# lap_start=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 31: 5063.5617353859425
#
# Processed data for day 3 lap 32
# lap_start=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 32: 5128.261031071217
#
# Processed data for day 3 lap 33
# lap_start=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 33: 5097.546275028039
#
# Processed data for day 3 lap 34
# lap_start=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 34: 5115.525513393859
#
# Processed data for day 3 lap 35
# lap_start=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 35: 5068.82875426529
#
# Processed data for day 3 lap 36
# lap_start=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 36: 5088.261708499171
#
# Processed data for day 3 lap 37
# lap_start=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 37: 5068.776713727902
#
# Processed data for day 3 lap 38
# lap_start=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 38: 5072.556120118899
#
# Processed data for day 3 lap 39
# lap_start=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 39: 5075.7124872947015
#
# Processed data for day 3 lap 40
# lap_start=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 40: 5089.189630301978
#
# Processed data for day 3 lap 41
# lap_start=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 41: 5054.849816863263
#
# Processed data for day 3 lap 42
# lap_start=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 42: 5095.5023770431935
#
# Processed data for day 3 lap 43
# lap_start=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 43: 5063.790078312235
#
# Processed data for day 3 lap 44
# lap_start=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 44: 5440.813917402113
#
# Processed data for day 3 lap 45
# lap_start=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 45: 4665.584539615914
#
# Processed data for day 3 lap 46
# lap_start=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 8, 58, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 46: 4482.863311977304
#
# Processed data for day 3 lap 47
# lap_start=datetime.datetime(2024, 7, 18, 21, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 47: 5146.462060842953
#
# Processed data for day 3 lap 48
# lap_start=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 48: 5052.49824545984
#
# Processed data for day 3 lap 49
# lap_start=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 57, 5, tzinfo=datetime.timezone.utc)
# get_lap_distance result for lap 49: 4717.041453247047
#
# Processed data for day 1 lap 1
# lap_start=datetime.datetime(2024, 7, 16, 15, 0, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 1: 846444.9773751661
#
# Processed data for day 1 lap 2
# lap_start=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 2: 745938.756712621
#
# Processed data for day 1 lap 3
# lap_start=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 3: 624473.3340006383
#
# Processed data for day 1 lap 4
# lap_start=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 4: 629948.0841042214
#
# Processed data for day 1 lap 5
# lap_start=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 5: 636756.5283181985
#
# Processed data for day 1 lap 6
# lap_start=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 6: 652379.8776730684
#
# Processed data for day 1 lap 7
# lap_start=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 7: 669097.0046211836
#
# Processed data for day 1 lap 8
# lap_start=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 8: 652374.505202404
#
# Processed data for day 1 lap 9
# lap_start=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 9: 629062.0999504155
#
# Processed data for day 1 lap 10
# lap_start=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 10: 670943.5462595281
#
# Processed data for day 1 lap 11
# lap_start=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 11: 666583.3029336224
#
# Processed data for day 1 lap 12
# lap_start=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 12: 591021.6757302512
#
# Processed data for day 1 lap 13
# lap_start=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 13: 601867.6532893152
#
# Processed data for day 1 lap 14
# lap_start=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 14: 590202.4072726899
#
# Processed data for day 1 lap 15
# lap_start=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 15: 602625.2745435858
#
# Processed data for day 1 lap 16
# lap_start=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 16: 618465.7384454232
#
# Processed data for day 1 lap 17
# lap_start=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 17: 626474.7136180066
#
# Processed data for day 1 lap 18
# lap_start=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 18: 649799.613212357
#
# Processed data for day 1 lap 19
# lap_start=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 19: 630957.9846723567
#
# Processed data for day 1 lap 20
# lap_start=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 20: 628896.0784637353
#
# Processed data for day 1 lap 21
# lap_start=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 21: 643093.4248029958
#
# Processed data for day 1 lap 22
# lap_start=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 22: 652243.5646553028
#
# Processed data for day 1 lap 23
# lap_start=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 23: 654393.6680295294
#
# Processed data for day 1 lap 24
# lap_start=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 24: 632792.4347154015
#
# Processed data for day 1 lap 25
# lap_start=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 25: 642748.0780535067
#
# Processed data for day 1 lap 26
# lap_start=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 26: 634858.9389371044
#
# Processed data for day 1 lap 27
# lap_start=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 27: 634400.4096127918
#
# Processed data for day 1 lap 28
# lap_start=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 16, 13, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 28: 511615.17033594137
#
# Processed data for day 1 lap 29
# lap_start=datetime.datetime(2024, 7, 16, 18, 19, 48, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 29: 670837.1684295017
#
# Processed data for day 1 lap 30
# lap_start=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 30: 643880.8320860828
#
# Processed data for day 1 lap 31
# lap_start=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 31: 626009.5456568686
#
# Processed data for day 1 lap 32
# lap_start=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 47, 36, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 32: 496479.4325773779
#
# Processed data for day 1 lap 33
# lap_start=datetime.datetime(2024, 7, 16, 18, 56, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 33: 597546.3519374253
#
# Processed data for day 1 lap 34
# lap_start=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 34: 566435.3217511948
#
# Processed data for day 1 lap 35
# lap_start=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 35: 596273.6122890566
#
# Processed data for day 1 lap 36
# lap_start=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 36: 581964.6530500057
#
# Processed data for day 1 lap 37
# lap_start=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 37: 629974.6663280718
#
# Processed data for day 1 lap 38
# lap_start=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 38: 619350.3520575344
#
# Processed data for day 1 lap 39
# lap_start=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 39: 568374.3779643759
#
# Processed data for day 1 lap 40
# lap_start=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 40: 582513.545241681
#
# Processed data for day 1 lap 41
# lap_start=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 41: 581037.8770110923
#
# Processed data for day 1 lap 42
# lap_start=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 42: 526006.9921881738
#
# Processed data for day 1 lap 43
# lap_start=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 43: 503344.70269979566
#
# Processed data for day 1 lap 44
# lap_start=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 44: 510004.8795861567
#
# Processed data for day 1 lap 45
# lap_start=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 45: 513088.8299917463
#
# Processed data for day 1 lap 46
# lap_start=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 39, 40, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 46: 501467.60848316114
#
# Processed data for day 3 lap 1
# lap_start=datetime.datetime(2024, 7, 18, 14, 17, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 1: 539612.4828941309
#
# Processed data for day 3 lap 2
# lap_start=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 2: 600062.2580840288
#
# Processed data for day 3 lap 3
# lap_start=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 3: 585415.6868956374
#
# Processed data for day 3 lap 4
# lap_start=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 4: 602073.0386972659
#
# Processed data for day 3 lap 5
# lap_start=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 5: 598940.3515772822
#
# Processed data for day 3 lap 6
# lap_start=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 6: 591835.7335247669
#
# Processed data for day 3 lap 7
# lap_start=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 7: 582027.7719551012
#
# Processed data for day 3 lap 8
# lap_start=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 8: 626204.9203372307
#
# Processed data for day 3 lap 9
# lap_start=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 9: 608283.3629069965
#
# Processed data for day 3 lap 10
# lap_start=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 10: 604640.8647599553
#
# Processed data for day 3 lap 11
# lap_start=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 11: 593220.7277085803
#
# Processed data for day 3 lap 12
# lap_start=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 12: 607958.7046500202
#
# Processed data for day 3 lap 13
# lap_start=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 13: 611331.0437065845
#
# Processed data for day 3 lap 14
# lap_start=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 14: 581768.724762119
#
# Processed data for day 3 lap 15
# lap_start=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 15: 616175.9272429032
#
# Processed data for day 3 lap 16
# lap_start=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 16: 616090.0693039967
#
# Processed data for day 3 lap 17
# lap_start=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 17: 619991.5077561648
#
# Processed data for day 3 lap 18
# lap_start=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 18: 616417.0790580024
#
# Processed data for day 3 lap 19
# lap_start=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 19: 608650.4663770805
#
# Processed data for day 3 lap 20
# lap_start=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 20: 607320.5100475744
#
# Processed data for day 3 lap 21
# lap_start=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 21: 600874.5154449994
#
# Processed data for day 3 lap 22
# lap_start=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 22: 608912.9082451127
#
# Processed data for day 3 lap 23
# lap_start=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 23: 600337.06022959
#
# Processed data for day 3 lap 24
# lap_start=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 24: 599903.206049299
#
# Processed data for day 3 lap 25
# lap_start=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 25: 589821.0459469539
#
# Processed data for day 3 lap 26
# lap_start=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 25, 58, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 26: 456056.4530103681
#
# Processed data for day 3 lap 27
# lap_start=datetime.datetime(2024, 7, 18, 17, 33, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 27: 630231.1782763057
#
# Processed data for day 3 lap 28
# lap_start=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 28: 566923.252917819
#
# Processed data for day 3 lap 29
# lap_start=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 29: 556347.4279881305
#
# Processed data for day 3 lap 30
# lap_start=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 30: 546156.706042999
#
# Processed data for day 3 lap 31
# lap_start=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 31: 528777.0935359853
#
# Processed data for day 3 lap 32
# lap_start=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 32: 548547.046560389
#
# Processed data for day 3 lap 33
# lap_start=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 33: 542025.5757011896
#
# Processed data for day 3 lap 34
# lap_start=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 34: 541910.9417454749
#
# Processed data for day 3 lap 35
# lap_start=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 35: 528726.5393831347
#
# Processed data for day 3 lap 36
# lap_start=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 36: 533636.6360668434
#
# Processed data for day 3 lap 37
# lap_start=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 37: 530369.1976189748
#
# Processed data for day 3 lap 38
# lap_start=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 38: 537366.2952870964
#
# Processed data for day 3 lap 39
# lap_start=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 39: 555912.3758085018
#
# Processed data for day 3 lap 40
# lap_start=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 40: 573095.1819480968
#
# Processed data for day 3 lap 41
# lap_start=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 41: 555037.9316392466
#
# Processed data for day 3 lap 42
# lap_start=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 42: 599459.9281941982
#
# Processed data for day 3 lap 43
# lap_start=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 43: 543992.7099907453
#
# Processed data for day 3 lap 44
# lap_start=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 44: 586578.8382777468
#
# Processed data for day 3 lap 45
# lap_start=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 45: 509144.6556161554
#
# Processed data for day 3 lap 46
# lap_start=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 8, 58, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 46: 498062.63267628144
#
# Processed data for day 3 lap 47
# lap_start=datetime.datetime(2024, 7, 18, 21, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 47: 604511.8590203943
#
# Processed data for day 3 lap 48
# lap_start=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 48: 586305.50823846
#
# Processed data for day 3 lap 49
# lap_start=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 57, 5, tzinfo=datetime.timezone.utc)
# lap_total_energy result for lap 49: 528113.999396192
#
# Processed data for day 1 lap 1
# lap_start=datetime.datetime(2024, 7, 16, 15, 0, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# get_speed_variance result for lap 1: 10.87254858065726
#
# Processed data for day 1 lap 2
# lap_start=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# get_speed_variance result for lap 2: 2.7063311230326206
#
# Processed data for day 1 lap 3
# ...
#
# Processed data for day 1 lap 32
# lap_start=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 47, 36, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 32: 0.04823565141414872
#
# Processed data for day 1 lap 33
# lap_start=datetime.datetime(2024, 7, 16, 18, 56, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 33: 0.03602782299536644
#
# Processed data for day 1 lap 34
# lap_start=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 34: 0.03725036213534576
#
# Processed data for day 1 lap 35
# lap_start=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 35: 0.04122511358835472
#
# Processed data for day 1 lap 36
# lap_start=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 36: 0.04336873645402658
#
# Processed data for day 1 lap 37
# lap_start=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 37: 0.04730434736911091
#
# Processed data for day 1 lap 38
# lap_start=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 38: 0.04769896958940309
#
# Processed data for day 1 lap 39
# lap_start=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 39: 0.04351321191159901
#
# Processed data for day 1 lap 40
# lap_start=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 40: 0.045616141032981894
#
# Processed data for day 1 lap 41
# lap_start=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 41: 0.04234743605217227
#
# Processed data for day 1 lap 42
# lap_start=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 42: 0.037914223191376994
#
# Processed data for day 1 lap 43
# lap_start=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 43: 0.0319101253628699
#
# Processed data for day 1 lap 44
# lap_start=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 44: 0.031439047734057916
#
# Processed data for day 1 lap 45
# lap_start=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 45: 0.032179835808092964
#
# Processed data for day 1 lap 46
# lap_start=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 39, 40, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 46: 0.027903216843298644
#
# Processed data for day 3 lap 1
# lap_start=datetime.datetime(2024, 7, 18, 14, 17, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 1: 0.036287979853809806
#
# Processed data for day 3 lap 2
# lap_start=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 2: 0.04909836821878815
#
# Processed data for day 3 lap 3
# lap_start=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 3: 0.038524891519044986
#
# Processed data for day 3 lap 4
# lap_start=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 4: 0.03949421979141133
#
# Processed data for day 3 lap 5
# lap_start=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 5: 0.03888087402573648
#
# Processed data for day 3 lap 6
# lap_start=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 6: 0.03944579853833039
#
# Processed data for day 3 lap 7
# lap_start=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 7: 0.03832142026989905
#
# Processed data for day 3 lap 8
# lap_start=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 8: 0.0392011826480288
#
# Processed data for day 3 lap 9
# lap_start=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 9: 0.039482337582648644
#
# Processed data for day 3 lap 10
# lap_start=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 10: 0.03863978227000528
#
# Processed data for day 3 lap 11
# lap_start=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 11: 0.04249888214196698
#
# Processed data for day 3 lap 12
# lap_start=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 12: 0.04345541876762345
#
# Processed data for day 3 lap 13
# lap_start=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 13: 0.03967128890864474
#
# Processed data for day 3 lap 14
# lap_start=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 14: 0.03727724178518023
#
# Processed data for day 3 lap 15
# lap_start=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 15: 0.03947370585363299
#
# Processed data for day 3 lap 16
# lap_start=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 16: 0.04197082610889172
#
# Processed data for day 3 lap 17
# lap_start=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 17: 0.042112454622138994
#
# Processed data for day 3 lap 18
# lap_start=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 18: 0.04160457198648646
#
# Processed data for day 3 lap 19
# lap_start=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 19: 0.0416875893845686
#
# Processed data for day 3 lap 20
# lap_start=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 20: 0.043504182881875485
#
# Processed data for day 3 lap 21
# lap_start=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 21: 0.04173355508695093
#
# Processed data for day 3 lap 22
# lap_start=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 22: 0.03961580908569059
#
# Processed data for day 3 lap 23
# lap_start=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 23: 0.040117724216114585
#
# Processed data for day 3 lap 24
# lap_start=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 24: 0.04137878207809576
#
# Processed data for day 3 lap 25
# lap_start=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 25: 0.04045753722839148
#
# Processed data for day 3 lap 26
# lap_start=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 25, 58, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 26: 0.038535167651404245
#
# Processed data for day 3 lap 27
# lap_start=datetime.datetime(2024, 7, 18, 17, 33, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 27: 0.038765077745160595
#
# Processed data for day 3 lap 28
# lap_start=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 28: 0.03645948745837451
#
# Processed data for day 3 lap 29
# lap_start=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 29: 0.03624214756753164
#
# Processed data for day 3 lap 30
# lap_start=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 30: 0.03476436759133212
#
# Processed data for day 3 lap 31
# lap_start=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 31: 0.033948764048761675
#
# Processed data for day 3 lap 32
# lap_start=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 32: 0.033663961087660094
#
# Processed data for day 3 lap 33
# lap_start=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 33: 0.03317985366310513
#
# Processed data for day 3 lap 34
# lap_start=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 34: 0.03416794828589575
#
# Processed data for day 3 lap 35
# lap_start=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 35: 0.03294582599487031
#
# Processed data for day 3 lap 36
# lap_start=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 36: 0.03258952200837944
#
# Processed data for day 3 lap 37
# lap_start=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 37: 0.02824164682015061
#
# Processed data for day 3 lap 38
# lap_start=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 38: 0.02674150463894578
#
# Processed data for day 3 lap 39
# lap_start=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 39: 0.02600039124697514
#
# Processed data for day 3 lap 40
# lap_start=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 40: 0.024787816963191052
#
# Processed data for day 3 lap 41
# lap_start=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 41: 0.025794517806594214
#
# Processed data for day 3 lap 42
# lap_start=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 42: 0.03506931012676619
#
# Processed data for day 3 lap 43
# lap_start=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 43: 0.026344747726768192
#
# Processed data for day 3 lap 44
# lap_start=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 44: 0.02446609147440702
#
# Processed data for day 3 lap 45
# lap_start=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 45: 0.024295686396291757
#
# Processed data for day 3 lap 46
# lap_start=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 8, 58, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 46: 0.02335626807210822
#
# Processed data for day 3 lap 47
# lap_start=datetime.datetime(2024, 7, 18, 21, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 47: 0.021788321676155256
#
# Processed data for day 3 lap 48
# lap_start=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 48: 0.023130143935842836
#
# Processed data for day 3 lap 49
# lap_start=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 57, 5, tzinfo=datetime.timezone.utc)
# get_rms_accel result for lap 49: 0.029181714464189705

# %%
def get_average_speed(start, end, client):
    return np.mean(lap_speed_ts(start, end, client).base)
lap_average_speeds = collect_lap_data(get_average_speed)
# Out:
# Processed data for day 1 lap 1
# lap_start=datetime.datetime(2024, 7, 16, 15, 0, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 1: 12.800596416687782
#
# Processed data for day 1 lap 2
# lap_start=datetime.datetime(2024, 7, 16, 15, 7, 4, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 2: 14.033308913048517
#
# Processed data for day 1 lap 3
# lap_start=datetime.datetime(2024, 7, 16, 15, 13, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 3: 11.867964699494191
#
# Processed data for day 1 lap 4
# lap_start=datetime.datetime(2024, 7, 16, 15, 20, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 4: 12.281399132944896
#
# Processed data for day 1 lap 5
# lap_start=datetime.datetime(2024, 7, 16, 15, 27, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 5: 12.891982999165323
#
# Processed data for day 1 lap 6
# lap_start=datetime.datetime(2024, 7, 16, 15, 33, 59, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 6: 13.504559943880784
#
# Processed data for day 1 lap 7
# lap_start=datetime.datetime(2024, 7, 16, 15, 40, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 7: 11.898167184787178
#
# Processed data for day 1 lap 8
# lap_start=datetime.datetime(2024, 7, 16, 15, 47, 45, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 8: 13.412259056333669
#
# Processed data for day 1 lap 9
# lap_start=datetime.datetime(2024, 7, 16, 15, 54, 10, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 9: 13.157111324903186
#
# Processed data for day 1 lap 10
# lap_start=datetime.datetime(2024, 7, 16, 16, 0, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 10: 13.379516911855015
#
# Processed data for day 1 lap 11
# lap_start=datetime.datetime(2024, 7, 16, 16, 7, 5, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 11: 13.822508739554053
#
# Processed data for day 1 lap 12
# lap_start=datetime.datetime(2024, 7, 16, 16, 13, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 12: 11.571432600558733
#
# Processed data for day 1 lap 13
# lap_start=datetime.datetime(2024, 7, 16, 16, 20, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 13: 10.883074184298064
#
# Processed data for day 1 lap 14
# lap_start=datetime.datetime(2024, 7, 16, 16, 28, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 14: 10.823199127169428
#
# Processed data for day 1 lap 15
# lap_start=datetime.datetime(2024, 7, 16, 16, 36, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 15: 11.147286032755764
#
# Processed data for day 1 lap 16
# lap_start=datetime.datetime(2024, 7, 16, 16, 44, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 16: 11.405483442184979
#
# Processed data for day 1 lap 17
# lap_start=datetime.datetime(2024, 7, 16, 16, 51, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 17: 11.35535066403992
#
# Processed data for day 1 lap 18
# lap_start=datetime.datetime(2024, 7, 16, 16, 59, 12, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 18: 12.326724423458042
#
# Processed data for day 1 lap 19
# lap_start=datetime.datetime(2024, 7, 16, 17, 6, 9, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 19: 12.080573886038371
#
# Processed data for day 1 lap 20
# lap_start=datetime.datetime(2024, 7, 16, 17, 13, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 20: 11.676601221340203
#
# Processed data for day 1 lap 21
# lap_start=datetime.datetime(2024, 7, 16, 17, 20, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 21: 12.110210495792483
#
# Processed data for day 1 lap 22
# lap_start=datetime.datetime(2024, 7, 16, 17, 27, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 22: 12.06406310557846
#
# Processed data for day 1 lap 23
# lap_start=datetime.datetime(2024, 7, 16, 17, 34, 43, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 23: 12.171989565669445
#
# Processed data for day 1 lap 24
# lap_start=datetime.datetime(2024, 7, 16, 17, 41, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 24: 12.480771418479078
#
# Processed data for day 1 lap 25
# lap_start=datetime.datetime(2024, 7, 16, 17, 48, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 25: 12.600815112649464
#
# Processed data for day 1 lap 26
# lap_start=datetime.datetime(2024, 7, 16, 17, 55, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 26: 12.405614214875312
#
# Processed data for day 1 lap 27
# lap_start=datetime.datetime(2024, 7, 16, 18, 2, 19, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 27: 12.483495916315384
#
# Processed data for day 1 lap 28
# lap_start=datetime.datetime(2024, 7, 16, 18, 9, 13, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 16, 13, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 28: 10.58392076823656
#
# Processed data for day 1 lap 29
# lap_start=datetime.datetime(2024, 7, 16, 18, 19, 48, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 29: 12.471529128924749
#
# Processed data for day 1 lap 30
# lap_start=datetime.datetime(2024, 7, 16, 18, 26, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 30: 12.686401227814292
#
# Processed data for day 1 lap 31
# lap_start=datetime.datetime(2024, 7, 16, 18, 33, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 31: 12.446247529814155
#
# Processed data for day 1 lap 32
# lap_start=datetime.datetime(2024, 7, 16, 18, 40, 37, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 18, 47, 36, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 32: 10.60029253659999
#
# Processed data for day 1 lap 33
# lap_start=datetime.datetime(2024, 7, 16, 18, 56, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 33: 11.50824749531646
#
# Processed data for day 1 lap 34
# lap_start=datetime.datetime(2024, 7, 16, 19, 4, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 34: 11.18581164213045
#
# Processed data for day 1 lap 35
# lap_start=datetime.datetime(2024, 7, 16, 19, 11, 52, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 35: 12.345529386215441
#
# Processed data for day 1 lap 36
# lap_start=datetime.datetime(2024, 7, 16, 19, 18, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 36: 12.74655131253549
#
# Processed data for day 1 lap 37
# lap_start=datetime.datetime(2024, 7, 16, 19, 25, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 37: 13.13919980834054
#
# Processed data for day 1 lap 38
# lap_start=datetime.datetime(2024, 7, 16, 19, 31, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 38: 13.93161291496854
#
# Processed data for day 1 lap 39
# lap_start=datetime.datetime(2024, 7, 16, 19, 38, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 39: 12.912921167071547
#
# Processed data for day 1 lap 40
# lap_start=datetime.datetime(2024, 7, 16, 19, 44, 33, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 40: 13.238577866880597
#
# Processed data for day 1 lap 41
# lap_start=datetime.datetime(2024, 7, 16, 19, 50, 58, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 41: 12.968734031580393
#
# Processed data for day 1 lap 42
# lap_start=datetime.datetime(2024, 7, 16, 19, 57, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 42: 11.834259496940662
#
# Processed data for day 1 lap 43
# lap_start=datetime.datetime(2024, 7, 16, 20, 4, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 43: 9.88521439778066
#
# Processed data for day 1 lap 44
# lap_start=datetime.datetime(2024, 7, 16, 20, 13, 8, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 44: 10.049862983762115
#
# Processed data for day 1 lap 45
# lap_start=datetime.datetime(2024, 7, 16, 20, 21, 29, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 45: 10.023640320087356
#
# Processed data for day 1 lap 46
# lap_start=datetime.datetime(2024, 7, 16, 20, 29, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 16, 20, 39, 40, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 46: 8.58822295461698
#
# Processed data for day 3 lap 1
# lap_start=datetime.datetime(2024, 7, 18, 14, 17, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 1: 10.054245719966834
#
# Processed data for day 3 lap 2
# lap_start=datetime.datetime(2024, 7, 18, 14, 26, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 2: 9.726885494192246
#
# Processed data for day 3 lap 3
# lap_start=datetime.datetime(2024, 7, 18, 14, 35, 2, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 3: 11.15880440460889
#
# Processed data for day 3 lap 4
# lap_start=datetime.datetime(2024, 7, 18, 14, 42, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 4: 10.818785322802247
#
# Processed data for day 3 lap 5
# lap_start=datetime.datetime(2024, 7, 18, 14, 50, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 5: 11.91819225165444
#
# Processed data for day 3 lap 6
# lap_start=datetime.datetime(2024, 7, 18, 14, 57, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 6: 11.882360020601828
#
# Processed data for day 3 lap 7
# lap_start=datetime.datetime(2024, 7, 18, 15, 4, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 7: 11.182748210455067
#
# Processed data for day 3 lap 8
# lap_start=datetime.datetime(2024, 7, 18, 15, 12, 34, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 8: 11.227035420883663
#
# Processed data for day 3 lap 9
# lap_start=datetime.datetime(2024, 7, 18, 15, 20, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 9: 11.903285103491623
#
# Processed data for day 3 lap 10
# lap_start=datetime.datetime(2024, 7, 18, 15, 27, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 10: 11.4349152349209
#
# Processed data for day 3 lap 11
# lap_start=datetime.datetime(2024, 7, 18, 15, 34, 56, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 11: 12.754032572558792
#
# Processed data for day 3 lap 12
# lap_start=datetime.datetime(2024, 7, 18, 15, 41, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 12: 12.587815293868305
#
# Processed data for day 3 lap 13
# lap_start=datetime.datetime(2024, 7, 18, 15, 48, 25, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 13: 11.932574194886358
#
# Processed data for day 3 lap 14
# lap_start=datetime.datetime(2024, 7, 18, 15, 55, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 14: 11.733667416175367
#
# Processed data for day 3 lap 15
# lap_start=datetime.datetime(2024, 7, 18, 16, 2, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 15: 12.353827424059105
#
# Processed data for day 3 lap 16
# lap_start=datetime.datetime(2024, 7, 18, 16, 9, 54, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 16: 12.661527009379375
#
# Processed data for day 3 lap 17
# lap_start=datetime.datetime(2024, 7, 18, 16, 16, 41, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 17: 12.744552193963797
#
# Processed data for day 3 lap 18
# lap_start=datetime.datetime(2024, 7, 18, 16, 23, 23, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 18: 12.480680226772087
#
# Processed data for day 3 lap 19
# lap_start=datetime.datetime(2024, 7, 18, 16, 30, 17, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 19: 12.598537893713388
#
# Processed data for day 3 lap 20
# lap_start=datetime.datetime(2024, 7, 18, 16, 37, 3, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 20: 12.276406664640074
#
# Processed data for day 3 lap 21
# lap_start=datetime.datetime(2024, 7, 18, 16, 44, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 21: 12.681995403648184
#
# Processed data for day 3 lap 22
# lap_start=datetime.datetime(2024, 7, 18, 16, 50, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 22: 12.060498570860409
#
# Processed data for day 3 lap 23
# lap_start=datetime.datetime(2024, 7, 18, 16, 57, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 23: 12.608334472596095
#
# Processed data for day 3 lap 24
# lap_start=datetime.datetime(2024, 7, 18, 17, 4, 40, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 24: 12.709407177891263
#
# Processed data for day 3 lap 25
# lap_start=datetime.datetime(2024, 7, 18, 17, 11, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 25: 12.31713620671499
#
# Processed data for day 3 lap 26
# lap_start=datetime.datetime(2024, 7, 18, 17, 18, 21, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 25, 58, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 26: 9.589408805811209
#
# Processed data for day 3 lap 27
# lap_start=datetime.datetime(2024, 7, 18, 17, 33, 1, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 27: 11.629493131174415
#
# Processed data for day 3 lap 28
# lap_start=datetime.datetime(2024, 7, 18, 17, 40, 44, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 28: 11.765189038488014
#
# Processed data for day 3 lap 29
# lap_start=datetime.datetime(2024, 7, 18, 17, 47, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 29: 11.383216343815985
#
# Processed data for day 3 lap 30
# lap_start=datetime.datetime(2024, 7, 18, 17, 55, 24, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 30: 11.06798120910514
#
# Processed data for day 3 lap 31
# lap_start=datetime.datetime(2024, 7, 18, 18, 3, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 31: 10.77775490364037
#
# Processed data for day 3 lap 32
# lap_start=datetime.datetime(2024, 7, 18, 18, 10, 57, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 32: 10.77843503732517
#
# Processed data for day 3 lap 33
# lap_start=datetime.datetime(2024, 7, 18, 18, 18, 53, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 33: 10.57562463797211
#
# Processed data for day 3 lap 34
# lap_start=datetime.datetime(2024, 7, 18, 18, 26, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 34: 11.09745090939562
#
# Processed data for day 3 lap 35
# lap_start=datetime.datetime(2024, 7, 18, 18, 34, 36, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 35: 10.675713466209194
#
# Processed data for day 3 lap 36
# lap_start=datetime.datetime(2024, 7, 18, 18, 42, 31, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 36: 10.096678668609986
#
# Processed data for day 3 lap 37
# lap_start=datetime.datetime(2024, 7, 18, 18, 50, 55, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 37: 8.53589508848269
#
# Processed data for day 3 lap 38
# lap_start=datetime.datetime(2024, 7, 18, 19, 0, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 38: 7.8154391459140315
#
# Processed data for day 3 lap 39
# lap_start=datetime.datetime(2024, 7, 18, 19, 11, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 39: 6.777819442388002
#
# Processed data for day 3 lap 40
# lap_start=datetime.datetime(2024, 7, 18, 19, 24, 7, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 40: 5.252608745308434
#
# Processed data for day 3 lap 41
# lap_start=datetime.datetime(2024, 7, 18, 19, 40, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 41: 6.297967901965659
#
# Processed data for day 3 lap 42
# lap_start=datetime.datetime(2024, 7, 18, 19, 53, 39, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 42: 3.8000189218366
#
# Processed data for day 3 lap 43
# lap_start=datetime.datetime(2024, 7, 18, 20, 16, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 43: 7.1728525335352975
#
# Processed data for day 3 lap 44
# lap_start=datetime.datetime(2024, 7, 18, 20, 27, 46, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 44: 6.455372512138416
#
# Processed data for day 3 lap 45
# lap_start=datetime.datetime(2024, 7, 18, 20, 41, 49, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 45: 6.068255745714716
#
# Processed data for day 3 lap 46
# lap_start=datetime.datetime(2024, 7, 18, 20, 54, 38, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 8, 58, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 46: 5.213256067030158
#
# Processed data for day 3 lap 47
# lap_start=datetime.datetime(2024, 7, 18, 21, 15, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 47: 4.978420431374374
#
# Processed data for day 3 lap 48
# lap_start=datetime.datetime(2024, 7, 18, 21, 32, 14, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 48: 5.392696494897053
#
# Processed data for day 3 lap 49
# lap_start=datetime.datetime(2024, 7, 18, 21, 47, 51, tzinfo=datetime.timezone.utc)
# lap_end=datetime.datetime(2024, 7, 18, 21, 57, 5, tzinfo=datetime.timezone.utc)
# get_average_speed result for lap 49: 8.515206774046305

# %%
import pandas as pd
import seaborn as sns

lap_numbers = np.arange(1, 1 + num_laps)
data_dict = {
    'Energy': lap_energies,
    'Distance (m)': lap_distances_m,
    'Speed Variance': lap_speed_variances,
    'Speed': lap_speeds,
    'Avg Speed': lap_average_speeds,
    'Avg Acceleration': lap_average_accelerations,
    'Avg Current': lap_average_currents,
    'Power Variance': lap_power_variances,
    'Current Variance': lap_current_variances,
    'Accel Variance': lap_accelerator_variances,
    'Avg Accel Variance': lap_accel_variance
}

# Create a DataFrame
df = pd.DataFrame(data_dict)

# Compute the correlation matrix for each driver
lap_distance_filter = distance_filter = np.logical_and(lap_distances_m > 5000, lap_distances_m < 5200)

for driver in driver_colours.keys():
    combined_filter = np.logical_and(distance_filter, lap_drivers == driver)
    filtered_corr_matrix = df[combined_filter].corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(filtered_corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', 
                vmin=-1, vmax=1, cbar=True, square=True, 
                linewidths=0.5, linecolor='gray')
    plt.title(f"{driver}- Lap Data Correlation Matrix", fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

def generate_driver_scatter_plot(dataset_a, dataset_b, data_filter: np.ndarray=None):
    """
    Automatically generates a scatter plot for two datasets with colors corresponding to drivers.

    Parameters:
    - dataset_a: Data for the x-axis
    - dataset_b: Data for the y-axis
    - data_filter: Boolean mask to filter the dataset

    The function will:
    - Create a scatter plot with colors assigned to each driver.
    - Label the axes with 'Dataset A' and 'Dataset B'.
    """
    
    # Create the scatter plot
    for driver, colour in driver_colours.items():
        # Select the data points where the driver is the same
        if data_filter is not None:
            combined_filter = np.logical_and(lap_drivers == driver, data_filter)
        else:
            combined_filter = lap_drivers == driver
        # Plot the data for the current driver
        plt.scatter(dataset_a[combined_filter], dataset_b[combined_filter], 
                    c=colour, label=f"Driver: {driver}")
    
    # Labeling the axes
    plt.xlabel("Dataset A")
    plt.ylabel("Dataset B")
    
    # Add a legend to the plot
    plt.legend(title="Drivers", loc='upper right')
    
    # Show the plot
    plt.show()

# %% [markdown]
# ## Validate Data
#
# I'll take a couple "squares" from the charts above to verify that they are correct

# %%
# Lap Energy vs. Lap Speed correlation
#     Alex: 0.48
#     Bryan: 0.21
#     Diego: 0.79
#     Phoebe: -0.59
generate_driver_scatter_plot(lap_speeds, lap_energies, distance_filter)
driver_filter = lambda driver_name: np.logical_and(lap_drivers == driver_name, distance_filter)
print(np.corrcoef(lap_speeds[driver_filter("Alex")], lap_energies[driver_filter("Alex")]))
print(np.corrcoef(lap_speeds[driver_filter("Bryan")], lap_energies[driver_filter("Bryan")]))
print(np.corrcoef(lap_speeds[driver_filter("Diego")], lap_energies[driver_filter("Diego")]))
print(np.corrcoef(lap_speeds[driver_filter("Phoebe")], lap_energies[driver_filter("Phoebe")]))

# Lap Energy vs. Speed Variance correlation
#     Alex: 0.12
#     Bryan: 0.48
#     Diego: 0.55
#     Phoebe: 0.84
generate_driver_scatter_plot(lap_speed_variances, lap_energies, distance_filter)
print(np.corrcoef(lap_speed_variances[driver_filter("Alex")], lap_energies[driver_filter("Alex")]))
print(np.corrcoef(lap_speed_variances[driver_filter("Bryan")], lap_energies[driver_filter("Bryan")]))
print(np.corrcoef(lap_speed_variances[driver_filter("Diego")], lap_energies[driver_filter("Diego")]))
print(np.corrcoef(lap_speed_variances[driver_filter("Phoebe")], lap_energies[driver_filter("Phoebe")]))
# Out:
# [[1.         0.48460406]
#  [0.48460406 1.        ]]
# [[1.         0.20726129]
#  [0.20726129 1.        ]]
# [[1.         0.79248938]
#  [0.79248938 1.        ]]
# [[ 1.         -0.58559969]
#  [-0.58559969  1.        ]]
# [[1.         0.11500613]
#  [0.11500613 1.        ]]
# [[1.         0.48079937]
#  [0.48079937 1.        ]]
# [[1.         0.55203363]
#  [0.55203363 1.        ]]
# [[1.         0.83538428]
#  [0.83538428 1.        ]]
